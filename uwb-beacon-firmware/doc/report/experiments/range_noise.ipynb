# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import mlab

# %%
df = pd.read_csv('range_noise.csv')
df.describe()
df = df[df.range < 1]

# %%
_, bins, _ = plt.hist(df.range, bins=50, normed=1)
mu, sigma = df.range.mean(), df.range.std()
plt.plot(bins, mlab.normpdf(bins, mu, sigma))
plt.xlabel('Range (m)')
plt.ylabel('Measurement count')
plt.title('Range measurement distribution ($\mu$ = {:.2f}, $\sigma$ = {:.3f} m)'.format(mu, sigma))
plt.gcf().savefig('range_noise.pdf')
